# %% [markdown]
# # CatPlot

# %%
import seaborn as sns
import pandas as pd 
import matplotlib.pyplot as plt

# %%
# Catplot :t provides a unified interface to several underlying axes-level categorical plot functions, such as stripplot, swarmplot, boxplot, violinplot, pointplot, barplot, and countplot.
#  ek single fxn ka use krk bht sare type k graph banana.

# Categorical scatterplots with catplot : -> stripplot() - with kind="strip" , -> swarmplot() with kind ="swarm"
# Categorical estimate plots with catplot : -> pointplot() - with kind="point" ,-> barplot() with kind ="bar" , -> countplot() with kind="count"
# Categorical distribution plot with catplot : -> boxplot() = with kind="box" , -> voilinplot() with kind ="violin" , -> boxenplot() with kind ="boxen"

df = sns.load_dataset("tips").head(100)
df
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# ..         ...   ...     ...    ...  ...     ...   ...
# 95       40.17  4.73    Male    Yes  Fri  Dinner     4
# 96       27.28  4.00    Male    Yes  Fri  Dinner     2
# 97       12.03  1.50    Male    Yes  Fri  Dinner     2
# 98       21.01  3.00    Male    Yes  Fri  Dinner     2
# 99       12.46  1.50    Male     No  Fri  Dinner     2
#
# [100 rows x 7 columns]

# %% [markdown]
# # Parameters

# %%
# kind : It essentially acts as a shortcut to select an underlying axes-level plotting function.

# height   : for changing the height of the whole graph


sns.catplot(x="size",y="tip",data=df,hue="sex",kind="point",palette="PRGn",height=10)
plt.show()
