# %% [markdown]
# # SciPy Constants

# %% [markdown]
# Useful for:
#
# Scientific computing
#
# Physics simulations
#
# Engineering calculations
#
# Unit conversion

# %% [markdown]
# .There are a veriety of constants that are included in the scipy.constant sub-packgae.
#
# .These constants are used in the general scientific area.
#
# .Let us see how these constant variables are imported and used.

# %% [markdown]
# 1. c              => Speed of light in vacuum.
# 2. speed_of_light => Speed of light in vacuum.
# 3. G => standard acceleration of gravity .
# 4. G => Newton Constant of gravitation.
# 5. E => Elementary charge
# 6. R => Molar gas constant
# 7. Alpha => Fine-structure constant
# 8. N-A => Avogadro constant
# 9. k => boltzmannn xonstant
# 10. Sigma => stefan-Bolzmannn constant
# 11. m_e =>Electronic mass
# 12. m_p => Proton mass
# 13. m_n => Neutron mass
# 14. H = Plank constant
# 15. Plank Constant => Plank constant h

# %%
#Import golden constant from the scipy

import scipy
print("scipy -golden ratio Value =%.18f"%scipy.constants.golden)
# Out:
# scipy -golden ratio Value =1.618033988749894903

# %%
from scipy.constants import find
find('boltzmann')
# Out:
# ['Boltzmann constant',
#  'Boltzmann constant in Hz/K',
#  'Boltzmann constant in eV/K',
#  'Boltzmann constant in inverse meter per kelvin',
#  'Stefan-Boltzmann constant']

# %%
scipy.constants.physical_constants['Boltzmann constant in Hz/K']
# Out:
# (20836619123.327576, 'Hz K^-1', 0.0)

# %%
from scipy import constants

print(constants.c)    # Speed of light
print(constants.h)    # Planck constant
print(constants.G)    # Gravitational constant
print(constants.g)    # Gravity
# Out:
# 299792458.0
# 6.62607015e-34
# 6.6743e-11
# 9.80665
