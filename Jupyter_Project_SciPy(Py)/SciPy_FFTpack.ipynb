# %% [markdown]
# # Scipy FFtpack =>

# %% [markdown]
# Fft stands for fast fourier transform

# %% [markdown]
# .It is an algorithm for computing DFT.DFT is a mathematical technique which is used in converting spatial data into frequency data .

# %% [markdown]
# .Scipy provides the fftpack module ,which is used to calculate Fourier Transformation.

# %% [markdown]
# .In the example , we will plot a simple periodic function of sin and see how the scipy.fft fxn will taransform it
