# %% [markdown]
# # Axis Plot

# %%
import matplotlib.pyplot as plt

# %%
x =[1,2,3,4,5]
y =[4,56,2,5,6]

plt.plot(x,y)

# plt.xticks(x,labels=["a","c","z","e","f"])
# plt.yticks(y)

# plt.xlim(0,10)  # uses for changing the limit of the axis 
# plt.ylim(0,90)

plt.axis([0,100,0,500])  # same uses for limits of axises respectively
plt.show()
