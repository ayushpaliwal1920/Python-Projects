# %% [markdown]
# # Save Fig

# %%
import matplotlib.pyplot as plt

# %%
# savefig :: plt.plot(x,y) then plt.savefiig(fname) then plt.show()

x =[1,2,3,4,5]
y =[4,5,2,6,1]

plt.plot(x,y)
plt.savefig("Line5",dpi=2000,facecolor="g",transparent=True,bbox_inches="tight")
plt.show()
