# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Data cleaning is the process of preparing data for analysis /Ml/Dl by removing or modifying data that is incorrect, incomplete , irrelevent,duplicated or improperly formatted.

# %% [markdown]
# # Steps for cleaning data :

# %% [markdown]
# 1.Handling Missing data
#
# 2.Outliner Detection and Handling
#
# 3.Data Scaling and transformation
#
# 4.Encoding Categorical variables
#
# 5.Handling Duplicated
#
# 6.Dealing with Inconsisting Data
